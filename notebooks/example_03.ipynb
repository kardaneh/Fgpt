# %% [markdown]
# # Isolating NetCDF W/R
#
# This notebook demonstrates how to isolate all dependencies of a procedure
# (subroutine or function) from their original module and generate self-contained
# versions that can be compiled and executed independently.
#
# In the example, `netcdf_demo` is a main program. Inside it, it calls:
#
# - `hdlerr`

# %%
# Notebook Setup

# %load_ext autoreload
# %autoreload 2

# Change to the Fgpt directory
# %cd /home/kardaneh/Fgpt

# Necessay imports 
import sys
from fgpt import Isolator
from fgpt.isolator import parse_args
# Out:
# /home/kardaneh/Fgpt
# /home/kardaneh/Fgpt/.venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# Attention on how the target and parent are defined:
# Because we deal with a main program, target and parent are the same.

sys.argv = [
    "my_program",

    "--rest_of_path", "Fgpt/examples",
    "--target_module", "netcdf_demo",
    "--work", "/home/kardaneh",

    "--target_model", "general",

    "--parent_subroutine", "netcdf_demo",

    "--target_subroutines", "netcdf_demo",

    "--openacc", "False",
    "--f2py", "False",
    "--py2jx", "False",
    "--tapenade", "False",

    "--mode", "jax",

    "--benchmark_dir", "/tmp/benchmark",

    "--config_path", "/home/kardaneh/Fgpt/template.yaml",

    "--vectorize",
    "kjpindex",
    "nvm",
    "npts",
]

# %%
args = parse_args()

isolator = Isolator(
    rest_of_path=args.rest_of_path,
    target_model=args.target_model,
    target_module=args.target_module,
    work=args.work,
    config_path=args.config_path,
    openacc=args.openacc,
    tapenade=args.tapenade,
    f2py=args.f2py,
    py2jx=args.py2jx,
)

isolator.run(
    benchmark_dir=args.benchmark_dir,
    vectorize=args.vectorize,
    mode=args.mode,
    parent_subroutine=args.parent_subroutine,
    target_subroutines=args.target_subroutines,
)
# Out:
# ╭────────────────────────────────── Fortran General purpose Transformer (Fgpt) ───────────────────────────────────╮
# │ 🚀 Starting Module: Isolator                                                                                    │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# [INFO] Successfully parsed file: /home/kardaneh/Fgpt/examples/netcdf_demo.f90
# [INFO] Normalizing names in parsed file: /home/kardaneh/Fgpt/examples/netcdf_demo.f90
# [INFO] Successfully normalized all names in the module
# [INFO] Starting isolation for target subroutines: ['netcdf_demo'] from parent subroutine: netcdf_demo
# ╭──────────────────────────────────────── TASK STARTED ────────────────────────────────────────╮
# │                                                                                              │
# │    🚀 Procedure Isolation/Transformation/Automatic Differentiation                           │
# │    📝 Isolation, Transformation, and Automatic Differentiation of procedures through FGPT    │
# │                                                                                              │
# │    🕒 11:40:05                                                                               │
# │                                                                                              │
# │    🔹 TARGET_MODULE: netcdf_demo                                                             │
# │                                                                                              │
# │                                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────╯
# [WARNING] ⚠ The internal subprogram part shoud not be present in main procedure. Remove!
# [INFO] Skipping Transformer initialization as f2np is disabled.
# [INFO] Skipping Python to JAX initialization as py2jx is disabled.
# [INFO]   Isolating target subroutine: 'netcdf_demo' (called from 'netcdf_demo')
# ╭───────────────────────────────────────────────── 🚀 Node Start ─────────────────────────────────────────────────╮
# │ 🧬 Entering node: Isolated Procedure                                                                            │
# │ 🔹 Parent → Child: netcdf_demo → netcdf_demo                                                                    │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# [INFO] The procedure type is main_program.
# [INFO] Separated type declaration with 2 entities into 2 individual declarations
# [INFO] Separated type declaration with 4 entities into 4 individual declarations
# [INFO] Separated type declaration with 6 entities into 6 individual declarations
# [INFO] Separated type declaration with 2 entities into 2 individual declarations
# [INFO] Separated type declaration with 4 entities into 4 individual declarations
# [INFO] Separated type declaration with 3 entities into 3 individual declarations
# [INFO] Found 1 nested procedure(s) in 'netcdf_demo':
# [INFO]    1. hdlerr
# [INFO] 🔄 Call recursively for 'hdlerr' from parent 'netcdf_demo'
# ╭───────────────────────────────────────────────── 🚀 Node Start ─────────────────────────────────────────────────╮
# │ 🧬 Entering node: Isolated Procedure                                                                            │
# │ 🔹 Parent → Child: netcdf_demo → hdlerr                                                                         │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# [INFO]   Call site 1: CALL hdlerr(status)
# [INFO]   Call site 2: CALL hdlerr(status)
# [INFO]   Call site 3: CALL hdlerr(status)
# [INFO]   Call site 4: CALL hdlerr(status)
# [INFO]   Call site 5: CALL hdlerr(status)
# [INFO]   Call site 6: CALL hdlerr(status)
# [INFO]   Call site 7: CALL hdlerr(status)
# [INFO]   Call site 8: CALL hdlerr(status)
# [INFO]   Call site 9: CALL hdlerr(status)
# [INFO]   Call site 10: CALL hdlerr(status)
# [INFO]   Call site 11: CALL hdlerr(status)
# [INFO]   Call site 12: CALL hdlerr(status)
# [INFO]   Call site 13: CALL hdlerr(status)
# [INFO]   Call site 14: CALL hdlerr(status)
# [INFO]   Call site 15: CALL hdlerr(status)
# [INFO]   Call site 16: CALL hdlerr(status)
# [INFO]   Call site 17: CALL hdlerr(status)
# [INFO]   Call site 18: CALL hdlerr(status)
# [INFO]   Call site 19: CALL hdlerr(status)
# [INFO]   Call site 20: CALL hdlerr(status)
# [INFO]   Call site 21: CALL hdlerr(status)
# [INFO]   Call site 22: CALL hdlerr(status)
# [INFO]   Call site 23: CALL hdlerr(status)
# [INFO]   Call site 24: CALL hdlerr(status)
# [INFO]   Call site 25: CALL hdlerr(status)
# [INFO]   Call site 26: CALL hdlerr(status)
# [INFO]   Call site 27: CALL hdlerr(status)
# [INFO]   Call site 28: CALL hdlerr(status)
# [INFO]   Call site 29: CALL hdlerr(status)
# [INFO]   Call site 30: CALL hdlerr(status)
# [INFO]   Call site 31: CALL hdlerr(status)
# [INFO]   Call site 32: CALL hdlerr(status)
# [INFO]   Call site 33: CALL hdlerr(status)
# [INFO]   Call site 34: CALL hdlerr(status)
# [INFO]   Call site 35: CALL hdlerr(status)
# [INFO]   Call site 36: CALL hdlerr(status)
# [INFO]   Call site 37: CALL hdlerr(status)
# [INFO]   Call site 38: CALL hdlerr(status)
# [INFO]   Call site 39: CALL hdlerr(status)
# [INFO]   Call site 40: CALL hdlerr(status)
# [INFO]   Call site 41: CALL hdlerr(status)
# [INFO]   Call site 42: CALL hdlerr(status)
# [INFO] The procedure type is subroutine.
# [INFO]  No nested procedures found in 'hdlerr' - proceeding to complete isolation
# [INFO] Induced INTENT for subroutine 'hdlerr':
# [INFO]   'istatus': 'IN'
# [INFO] Successfully parsed string!
# [INFO] 📁 Created parent function directory: /home/kardaneh/Fgpt/netcdf_demo/hdlerr
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Processing initialization completed!
# [INFO] Processing initialization completed!
# [INFO] Declarations and allocations processed successfully
# [INFO] Successfully parsed string!
# [INFO] Successfully parsed module code
# [INFO] Successfully parsed main program code
# [INFO] Inserted I/O statements at beginning of Execution_Part in procedure: hdlerr
# [INFO] Successfully updated the global module
# [INFO] Successfully wrote code to file: /home/kardaneh/Fgpt/netcdf_demo/hdlerr/module_global_hdlerr.f90
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully parsed statement: READ(1363, IOSTAT = ier) istatus
# IF (ier /= 0) THEN
#   WRITE(*, *) 'Error reading from file for istatus. ', ' IOSTAT : ', ier
# END IF
# [INFO] Processing initialization completed!
# [INFO] Processing initialization completed!
# [INFO] Declarations and allocations processed successfully
# [INFO] Inserted I/O statements at beginning of Execution_Part in procedure: hdlerr
# [INFO] Successfully parsed statement: CALL SYSTEM_CLOCK(ic0, icr, ic)
# start_time = ic0 * 1.0 / icr
# [INFO] Successfully parsed statement: CALL SYSTEM_CLOCK(ic0, icr, ic)
# stop_time = ic0 * 1.0 / icr
# WRITE(*, *) "Execution time : ", stop_time - start_time
# OPEN(UNIT = 1363, FILE = '/home/kardaneh/Fgpt/benchmark/hdlerr/time.txt', STATUS = 'unknown', POSITION = 'append')
# WRITE(1363, *) stop_time - start_time
# CLOSE(UNIT = 1363)
# [INFO] Successfully parsed statement: OPEN(UNIT = 1363, FILE = '/home/kardaneh/Fgpt/benchmark/hdlerr/output.bin',
# FORM = 'unformatted', STATUS = 'replace')
# CLOSE(UNIT = 1363)
# [INFO] Successfully updated the main program
# [INFO] Successfully wrote code to file: /home/kardaneh/Fgpt/netcdf_demo/hdlerr/main_hdlerr.f90
# [INFO] Compiling and running in /home/kardaneh/Fgpt/netcdf_demo/hdlerr...
# Tapenade files detected (adjoint: , tangent: ) - enabling Tapenade runtime
# rm -rf obj hdlerr mod /home/kardaneh/Fgpt/netcdf_demo/hdlerr/hdlerr.txt
# Cleaned build artifacts.
# Tapenade files detected (adjoint: , tangent: ) - enabling Tapenade runtime
# rm -rf obj hdlerr mod /home/kardaneh/Fgpt/netcdf_demo/hdlerr/hdlerr.txt
# Cleaned build artifacts.
# mpif90 -Wall -g -O0 -Kieee -Ktrap=fp -Mbounds -traceback -r8 -i4 -I/data/ssivanes/modipsl_truck_opt/modeles/IOIPSL/inc -I/data/ssivanes/modipsl_truck_opt/modeles/XIOS/inc -I/data/ssivanes/modipsl_truck_opt/modeles/ORCHIDEE/inc -I/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-x86_64/netcdf-c/4.7.4-nvhpc-21.9-qnkr5ug7ksav3drxwijn2dc4t75yzota/include -I/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-x86_64/netcdf-fortran/4.5.3-nvhpc-21.9-ea7lcxvrs3byj4iwmp7eul7vfz5zhavo/include -c /home/kardaneh/Fgpt/netcdf_demo/hdlerr/module_global_hdlerr.f90 -o obj/module_global_hdlerr.o -module mod >> /home/kardaneh/Fgpt/netcdf_demo/hdlerr/hdlerr.txt 2>&1
# mpif90 -Wall -g -O0 -Kieee -Ktrap=fp -Mbounds -traceback -r8 -i4 -I/data/ssivanes/modipsl_truck_opt/modeles/IOIPSL/inc -I/data/ssivanes/modipsl_truck_opt/modeles/XIOS/inc -I/data/ssivanes/modipsl_truck_opt/modeles/ORCHIDEE/inc -I/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-x86_64/netcdf-c/4.7.4-nvhpc-21.9-qnkr5ug7ksav3drxwijn2dc4t75yzota/include -I/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-x86_64/netcdf-fortran/4.5.3-nvhpc-21.9-ea7lcxvrs3byj4iwmp7eul7vfz5zhavo/include -c /home/kardaneh/Fgpt/netcdf_demo/hdlerr/main_hdlerr.f90 -o obj/main_hdlerr.o -module mod >> /home/kardaneh/Fgpt/netcdf_demo/hdlerr/hdlerr.txt 2>&1
# mpicc -Wall -g -O0 -Kieee -Ktrap=fp -traceback -DUNDERSCORE -fopenmp -c /data/kardaneh/tapenade/tapenade_3.16/ADFirstAidKit/adStack.c -o obj/adStack.o >> /home/kardaneh/Fgpt/netcdf_demo/hdlerr/hdlerr.txt 2>&1
# Linking hdlerr ...
# Including Tapenade object files for automatic differentiation.
# mpif90 -Wall -g -O0 -Kieee -Ktrap=fp -Mbounds -traceback -r8 -i4 obj/module_global_hdlerr.o obj/main_hdlerr.o obj/adStack.o -L/data/ssivanes/modipsl_truck_opt/modeles/ORCHIDEE/lib -lorchidee -L/data/ssivanes/modipsl_truck_opt/modeles/IOIPSL/lib -lioipsl -L/data/ssivanes/modipsl_truck_opt/modeles/XIOS/lib -lxios -lstdc++ -L/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-x86_64/netcdf-c/4.7.4-nvhpc-21.9-qnkr5ug7ksav3drxwijn2dc4t75yzota/lib -lnetcdf -L/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-x86_64/netcdf-fortran/4.5.3-nvhpc-21.9-ea7lcxvrs3byj4iwmp7eul7vfz5zhavo/lib -lnetcdff -o hdlerr >> /home/kardaneh/Fgpt/netcdf_demo/hdlerr/hdlerr.txt 2>&1
# Build complete: hdlerr
# [INFO] Compilation process completed!
# [INFO] Benchmark files exist. Now running the unit tests ...
#  --- inside the main program ---
#  --- inside the declaration_initialization routine for hdlerr ---
#  --- inside the read_dummy routine for hdlerr ---
#  Execution time :     0.000000000000000
# [INFO] Execution completed in /home/kardaneh/Fgpt/netcdf_demo/hdlerr
# [INFO] Successfully wrote code to file: /home/kardaneh/Fgpt/examples/netcdf_demo.f90
# ╭─────────────────────────────────────────────── ✅ Node Complete ────────────────────────────────────────────────╮
# │ Exiting node: Isolated Procedure                                                                                │
# │ Duration: 1.47s                                                                                                 │
# │ ✅ Done isolating → hdlerr                                                                                      │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# [INFO] Induced INTENT for subroutine 'netcdf_demo':
# [INFO] Successfully parsed string!
# [INFO] 📁 Created parent function directory: /home/kardaneh/Fgpt/netcdf_demo/netcdf_demo
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Processing initialization completed!
# [INFO] Processing initialization completed!
# [INFO] Declarations and allocations processed successfully
# [INFO] Successfully parsed string!
# [WARNING] ⚠ Procedure 'netcdf_demo' is a main program; it does not need to be added to the global module.
# [INFO] Successfully parsed module code
# [INFO] Successfully parsed main program code
# [INFO] Inserted I/O statements at beginning of Execution_Part in procedure: netcdf_demo
# [INFO] Successfully updated the global module
# [INFO] Successfully wrote code to file: /home/kardaneh/Fgpt/netcdf_demo/netcdf_demo/module_global_netcdf_demo.f90
# [INFO] The procedure type is main_program. No need fro call statment!
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Processing initialization completed!
# [INFO] Processing initialization completed!
# [INFO] Declarations and allocations processed successfully
# [INFO] Inserted I/O statements at beginning of Execution_Part in procedure: netcdf_demo
# [INFO] Successfully parsed statement: CALL SYSTEM_CLOCK(ic0, icr, ic)
# start_time = ic0 * 1.0 / icr
# [INFO] Successfully parsed statement: CALL SYSTEM_CLOCK(ic0, icr, ic)
# stop_time = ic0 * 1.0 / icr
# WRITE(*, *) "Execution time : ", stop_time - start_time
# OPEN(UNIT = 1363, FILE = '/home/kardaneh/Fgpt/benchmark/netcdf_demo/time.txt', STATUS = 'unknown', POSITION =
# 'append')
# WRITE(1363, *) stop_time - start_time
# CLOSE(UNIT = 1363)
# [INFO] Successfully parsed statement: OPEN(UNIT = 1363, FILE =
# '/home/kardaneh/Fgpt/benchmark/netcdf_demo/output.bin', FORM = 'unformatted', STATUS = 'replace')
# CLOSE(UNIT = 1363)
# [INFO] Successfully updated the main program
# [INFO] Successfully wrote code to file: /home/kardaneh/Fgpt/netcdf_demo/netcdf_demo/main_netcdf_demo.f90
# [INFO] Compiling and running in /home/kardaneh/Fgpt/netcdf_demo/netcdf_demo...
# Tapenade files detected (adjoint: , tangent: ) - enabling Tapenade runtime
# rm -rf obj netcdf_demo mod /home/kardaneh/Fgpt/netcdf_demo/netcdf_demo/netcdf_demo.txt
# Cleaned build artifacts.
# Tapenade files detected (adjoint: , tangent: ) - enabling Tapenade runtime
# rm -rf obj netcdf_demo mod /home/kardaneh/Fgpt/netcdf_demo/netcdf_demo/netcdf_demo.txt
# Cleaned build artifacts.
# mpif90 -Wall -g -O0 -Kieee -Ktrap=fp -Mbounds -traceback -r8 -i4 -I/data/ssivanes/modipsl_truck_opt/modeles/IOIPSL/inc -I/data/ssivanes/modipsl_truck_opt/modeles/XIOS/inc -I/data/ssivanes/modipsl_truck_opt/modeles/ORCHIDEE/inc -I/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-x86_64/netcdf-c/4.7.4-nvhpc-21.9-qnkr5ug7ksav3drxwijn2dc4t75yzota/include -I/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-x86_64/netcdf-fortran/4.5.3-nvhpc-21.9-ea7lcxvrs3byj4iwmp7eul7vfz5zhavo/include -c /home/kardaneh/Fgpt/netcdf_demo/netcdf_demo/module_global_netcdf_demo.f90 -o obj/module_global_netcdf_demo.o -module mod >> /home/kardaneh/Fgpt/netcdf_demo/netcdf_demo/netcdf_demo.txt 2>&1
# mpif90 -Wall -g -O0 -Kieee -Ktrap=fp -Mbounds -traceback -r8 -i4 -I/data/ssivanes/modipsl_truck_opt/modeles/IOIPSL/inc -I/data/ssivanes/modipsl_truck_opt/modeles/XIOS/inc -I/data/ssivanes/modipsl_truck_opt/modeles/ORCHIDEE/inc -I/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-x86_64/netcdf-c/4.7.4-nvhpc-21.9-qnkr5ug7ksav3drxwijn2dc4t75yzota/include -I/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-x86_64/netcdf-fortran/4.5.3-nvhpc-21.9-ea7lcxvrs3byj4iwmp7eul7vfz5zhavo/include -c /home/kardaneh/Fgpt/netcdf_demo/netcdf_demo/main_netcdf_demo.f90 -o obj/main_netcdf_demo.o -module mod >> /home/kardaneh/Fgpt/netcdf_demo/netcdf_demo/netcdf_demo.txt 2>&1
# mpicc -Wall -g -O0 -Kieee -Ktrap=fp -traceback -DUNDERSCORE -fopenmp -c /data/kardaneh/tapenade/tapenade_3.16/ADFirstAidKit/adStack.c -o obj/adStack.o >> /home/kardaneh/Fgpt/netcdf_demo/netcdf_demo/netcdf_demo.txt 2>&1
# Linking netcdf_demo ...
# Including Tapenade object files for automatic differentiation.
# mpif90 -Wall -g -O0 -Kieee -Ktrap=fp -Mbounds -traceback -r8 -i4 obj/module_global_netcdf_demo.o obj/main_netcdf_demo.o obj/adStack.o -L/data/ssivanes/modipsl_truck_opt/modeles/ORCHIDEE/lib -lorchidee -L/data/ssivanes/modipsl_truck_opt/modeles/IOIPSL/lib -lioipsl -L/data/ssivanes/modipsl_truck_opt/modeles/XIOS/lib -lxios -lstdc++ -L/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-x86_64/netcdf-c/4.7.4-nvhpc-21.9-qnkr5ug7ksav3drxwijn2dc4t75yzota/lib -lnetcdf -L/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-x86_64/netcdf-fortran/4.5.3-nvhpc-21.9-ea7lcxvrs3byj4iwmp7eul7vfz5zhavo/lib -lnetcdff -o netcdf_demo >> /home/kardaneh/Fgpt/netcdf_demo/netcdf_demo/netcdf_demo.txt 2>&1
# Build complete: netcdf_demo
# [INFO] Compilation process completed!
# [INFO] Benchmark files exist. Now running the unit tests ...
# --- Writing sample_in.nc ---
# --- sample_in.nc written ---
# --- Reading sample_in.nc ---
#  glamf max/min:    135.0000  -180.0000
#  gphit max/min:     60.0000   -90.0000
#  tmask max/min:      1.0000     0.0000
#  Bottom index maximum:    5.0
# --- Writing sample_out.nc ---
# --- sample_out.nc written ---
# Program completed successfully!
#  Execution time :    6.9999999999999999E-006
# [INFO] Execution completed in /home/kardaneh/Fgpt/netcdf_demo/netcdf_demo
# [INFO] Successfully wrote code to file: /home/kardaneh/Fgpt/examples/netcdf_demo.f90
# ╭─────────────────────────────────────────────── ✅ Node Complete ────────────────────────────────────────────────╮
# │ Exiting node: Isolated Procedure                                                                                │
# │ Duration: 3.47s                                                                                                 │
# │ ✅ Done isolating → netcdf_demo                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
