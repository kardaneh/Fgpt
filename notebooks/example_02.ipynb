# %% [markdown]
# # Isolating All: From Bottom to Top
#
# This notebook demonstrates how to isolate all dependencies of a procedure
# (subroutine or function) from their original module and generate self-contained
# versions that can be compiled and executed independently.
#
# In the example, `test_procedures` is a main program. Inside it, the following
# procedures are called:
#
# - `set_data`
# - `process_data`
# - `display_data`
# - `dump_to_file`
# - `reset_data`
# - `scale_data`
# - `compute_average`
#
# The isolation starts from the innermost procedure, derives all of its
# dependencies, and isolates them. Then it moves up one level, and up again,
# until the whole call tree has been processed.

# %%
# Notebook Setup

# %load_ext autoreload
# %autoreload 2

# Change to the Fgpt directory
# %cd /home/kardaneh/Fgpt

# Necessay imports 
import sys
from fgpt import Isolator
from fgpt.isolator import parse_args
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /home/kardaneh/Fgpt

# %%
# Attention on how the target and parent are defined:
# Because we deal with a main program, target and parent are the same.

sys.argv = [
    "my_program",

    "--rest_of_path", "Fgpt/examples",
    "--target_module", "example_01",
    "--work", "/home/kardaneh",

    "--target_model", "general",

    "--parent_subroutine", "test_procedures",

    "--target_subroutines", "test_procedures",

    "--openacc", "False",
    "--f2py", "False",
    "--py2jx", "False",
    "--tapenade", "False",

    "--mode", "jax",

    "--benchmark_dir", "/tmp/benchmark",

    "--config_path", "/home/kardaneh/Fgpt/template.yaml",

    "--vectorize",
    "kjpindex",
    "nvm",
    "npts",
]

# %%
args = parse_args()

isolator = Isolator(
    rest_of_path=args.rest_of_path,
    target_model=args.target_model,
    target_module=args.target_module,
    work=args.work,
    config_path=args.config_path,
    openacc=args.openacc,
    tapenade=args.tapenade,
    f2py=args.f2py,
    py2jx=args.py2jx,
)

isolator.run(
    benchmark_dir=args.benchmark_dir,
    vectorize=args.vectorize,
    mode=args.mode,
    parent_subroutine=args.parent_subroutine,
    target_subroutines=args.target_subroutines,
)
# Out:
# ╭────────────────────────────────── Fortran General purpose Transformer (Fgpt) ───────────────────────────────────╮
# │ 🚀 Starting Module: Isolator                                                                                    │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# [INFO] Successfully parsed file: /home/kardaneh/Fgpt/examples/example_01_org.fgpt
# [INFO] Normalizing names in parsed file: /home/kardaneh/Fgpt/examples/example_01_org.fgpt
# [INFO] Successfully normalized all names in the module
# [INFO] Starting isolation for target subroutines: ['test_procedures'] from parent subroutine: test_procedures
# ╭──────────────────────────────────────── TASK STARTED ────────────────────────────────────────╮
# │                                                                                              │
# │    🚀 Procedure Isolation/Transformation/Automatic Differentiation                           │
# │    📝 Isolation, Transformation, and Automatic Differentiation of procedures through FGPT    │
# │                                                                                              │
# │    🕒 11:04:27                                                                               │
# │                                                                                              │
# │    🔹 TARGET_MODULE: example_01                                                              │
# │                                                                                              │
# │                                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────╯
# [WARNING] ⚠ Suffix found in function 'compute_average': RESULT(avg)
# [INFO] Function compute_average is called inside the assignment average = compute_average(data_array, n, variance,
# stddev) of procedure test_procedures.
# [INFO] Skipping Transformer initialization as f2np is disabled.
# [INFO] Skipping Python to JAX initialization as py2jx is disabled.
# [INFO]   Isolating target subroutine: 'test_procedures' (called from 'test_procedures')
# ╭───────────────────────────────────────────────── 🚀 Node Start ─────────────────────────────────────────────────╮
# │ 🧬 Entering node: Isolated Procedure                                                                            │
# │ 🔹 Parent → Child: test_procedures → test_procedures                                                            │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# [INFO] The procedure type is main_program.
# [INFO] Separated type declaration with 3 entities into 3 individual declarations
# [INFO] Found 7 nested procedure(s) in 'test_procedures':
# [INFO]    1. compute_average
# [INFO] 🔄 Call recursively for 'compute_average' from parent 'test_procedures'
# ╭───────────────────────────────────────────────── 🚀 Node Start ─────────────────────────────────────────────────╮
# │ 🧬 Entering node: Isolated Procedure                                                                            │
# │ 🔹 Parent → Child: test_procedures → compute_average                                                            │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# [INFO]   Call site 1: average = compute_average(data_array, n, variance, stddev)
# [INFO] The procedure type is function.
# [INFO]  No nested procedures found in 'compute_average' - proceeding to complete isolation
# [INFO] Induced INTENT for subroutine 'compute_average':
# [INFO]   'arr': 'IN'
# [INFO]   'size': 'IN'
# [INFO]   'variance': 'OUT'
# [INFO]   'stddev': 'OUT'
# [INFO] 📁 Created parent function directory: /home/kardaneh/Fgpt/example_01/compute_average
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Processing initialization completed!
# [INFO] Processing initialization completed!
# [INFO] Declarations and allocations processed successfully
# [INFO] Successfully parsed string!
# [INFO] Successfully parsed module code
# [INFO] Successfully parsed main program code
# [INFO] Inserted I/O statements at beginning of Execution_Part in procedure: compute_average
# [INFO] Successfully updated the global module
# [INFO] Successfully wrote code to file:
# /home/kardaneh/Fgpt/example_01/compute_average/module_global_compute_average.f90
# [INFO] Allocatable declaration: REAL, ALLOCATABLE, DIMENSION(:) :: arr
# [INFO] Allocate statement: ALLOCATE(arr(size))
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Combined statement: REAL, DIMENSION(size) :: arr
# [INFO] Successfully parsed statement: IF (.NOT. ALLOCATED(arr)) THEN
#   ALLOCATE(arr(size))
# END IF
# [INFO] Successfully generated allocation statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully parsed statement: READ(1363, IOSTAT = ier) avg
# IF (ier /= 0) THEN
#   WRITE(*, *) 'Error reading from file for avg. ', ' IOSTAT : ', ier
# END IF
# [INFO] Successfully parsed statement: READ(1363, IOSTAT = ier) size
# IF (ier /= 0) THEN
#   WRITE(*, *) 'Error reading from file for size. ', ' IOSTAT : ', ier
# END IF
# [INFO] Successfully parsed statement: READ(1363, IOSTAT = ier) stddev
# IF (ier /= 0) THEN
#   WRITE(*, *) 'Error reading from file for stddev. ', ' IOSTAT : ', ier
# END IF
# [INFO] Successfully parsed statement: READ(1363, IOSTAT = ier) variance
# IF (ier /= 0) THEN
#   WRITE(*, *) 'Error reading from file for variance. ', ' IOSTAT : ', ier
# END IF
# [INFO] Processing initialization completed!
# [INFO] Successfully parsed statement: READ(1363, IOSTAT = ier) arr
# IF (ier /= 0) THEN
#   WRITE(*, *) 'Error reading from file for arr. ', ' IOSTAT : ', ier
# END IF
# [INFO] Processing initialization completed!
# [INFO] Declarations and allocations processed successfully
# [INFO] Inserted I/O statements at beginning of Execution_Part in procedure: compute_average
# [INFO] Successfully parsed statement: CALL SYSTEM_CLOCK(ic0, icr, ic)
# start_time = ic0 * 1.0 / icr
# [INFO] Successfully parsed statement: CALL SYSTEM_CLOCK(ic0, icr, ic)
# stop_time = ic0 * 1.0 / icr
# WRITE(*, *) "Execution time : ", stop_time - start_time
# OPEN(UNIT = 1363, FILE = '/home/kardaneh/Fgpt/benchmark/compute_average/time.txt', STATUS = 'unknown', POSITION =
# 'append')
# WRITE(1363, *) stop_time - start_time
# CLOSE(UNIT = 1363)
# [INFO] Successfully parsed statement: OPEN(UNIT = 1363, FILE =
# '/home/kardaneh/Fgpt/benchmark/compute_average/output.bin', FORM = 'unformatted', STATUS = 'replace')
# WRITE(1363) avg
# WRITE(1363) stddev
# WRITE(1363) variance
# CLOSE(UNIT = 1363)
# [INFO] Successfully updated the main program
# [INFO] Successfully wrote code to file: /home/kardaneh/Fgpt/example_01/compute_average/main_compute_average.f90
# [INFO] Compiling and running in /home/kardaneh/Fgpt/example_01/compute_average...
# Tapenade files detected (adjoint: , tangent: ) - enabling Tapenade runtime
# rm -rf obj compute_average mod /home/kardaneh/Fgpt/example_01/compute_average/compute_average.txt
# Cleaned build artifacts.
# Tapenade files detected (adjoint: , tangent: ) - enabling Tapenade runtime
# rm -rf obj compute_average mod /home/kardaneh/Fgpt/example_01/compute_average/compute_average.txt
# Cleaned build artifacts.
# mpif90 -Wall -g -O0 -Kieee -Ktrap=fp -Mbounds -traceback -r8 -i4 -I/data/ssivanes/modipsl_truck_opt/modeles/IOIPSL/inc -I/data/ssivanes/modipsl_truck_opt/modeles/XIOS/inc -I/data/ssivanes/modipsl_truck_opt/modeles/ORCHIDEE/inc -I/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-c/4.7.4-nvhpc-21.9-3ljfhvpzxouhzpusyuu6s5alubl5el7p/include -I/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-fortran/4.5.3-nvhpc-21.9-nf3dmves2qwgafsadgnawv45fiecf5ss/include -c /home/kardaneh/Fgpt/example_01/compute_average/module_global_compute_average.f90 -o obj/module_global_compute_average.o -module mod >> /home/kardaneh/Fgpt/example_01/compute_average/compute_average.txt 2>&1
# mpif90 -Wall -g -O0 -Kieee -Ktrap=fp -Mbounds -traceback -r8 -i4 -I/data/ssivanes/modipsl_truck_opt/modeles/IOIPSL/inc -I/data/ssivanes/modipsl_truck_opt/modeles/XIOS/inc -I/data/ssivanes/modipsl_truck_opt/modeles/ORCHIDEE/inc -I/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-c/4.7.4-nvhpc-21.9-3ljfhvpzxouhzpusyuu6s5alubl5el7p/include -I/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-fortran/4.5.3-nvhpc-21.9-nf3dmves2qwgafsadgnawv45fiecf5ss/include -c /home/kardaneh/Fgpt/example_01/compute_average/main_compute_average.f90 -o obj/main_compute_average.o -module mod >> /home/kardaneh/Fgpt/example_01/compute_average/compute_average.txt 2>&1
# mpicc -Wall -g -O0 -Kieee -Ktrap=fp -traceback -DUNDERSCORE -fopenmp -c /data/kardaneh/tapenade/tapenade_3.16/ADFirstAidKit/adStack.c -o obj/adStack.o >> /home/kardaneh/Fgpt/example_01/compute_average/compute_average.txt 2>&1
# Linking compute_average ...
# Including Tapenade object files for automatic differentiation.
# mpif90 -Wall -g -O0 -Kieee -Ktrap=fp -Mbounds -traceback -r8 -i4 obj/module_global_compute_average.o obj/main_compute_average.o obj/adStack.o -L/data/ssivanes/modipsl_truck_opt/modeles/ORCHIDEE/lib -lorchidee -L/data/ssivanes/modipsl_truck_opt/modeles/IOIPSL/lib -lioipsl -L/data/ssivanes/modipsl_truck_opt/modeles/XIOS/lib -lxios -lstdc++ -L/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-c/4.7.4-nvhpc-21.9-3ljfhvpzxouhzpusyuu6s5alubl5el7p/lib -lnetcdf -L/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-fortran/4.5.3-nvhpc-21.9-nf3dmves2qwgafsadgnawv45fiecf5ss/lib -lnetcdff -o compute_average >> /home/kardaneh/Fgpt/example_01/compute_average/compute_average.txt 2>&1
# Build complete: compute_average
# [INFO] Compilation process completed!
# [INFO] Benchmark files exist. Now running the unit tests ...
#  --- inside the main program ---
#  --- inside the declaration_initialization routine for compute_average ---
#  --- inside the read_dummy routine for compute_average ---
#  Average computed!
#  Execution time :    7.9999999999999996E-006
# [INFO] Execution completed in /home/kardaneh/Fgpt/example_01/compute_average
# [INFO] Successfully wrote code to file: /home/kardaneh/Fgpt/examples/example_01.f90
# ╭─────────────────────────────────────────────── ✅ Node Complete ────────────────────────────────────────────────╮
# │ Exiting node: Isolated Procedure                                                                                │
# │ Duration: 1.04s                                                                                                 │
# │ ✅ Done isolating → compute_average                                                                             │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# [INFO]    2. set_data
# [INFO] 🔄 Call recursively for 'set_data' from parent 'test_procedures'
# ╭───────────────────────────────────────────────── 🚀 Node Start ─────────────────────────────────────────────────╮
# │ 🧬 Entering node: Isolated Procedure                                                                            │
# │ 🔹 Parent → Child: test_procedures → set_data                                                                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# [INFO]   Call site 1: CALL set_data(data_array, n, 0.0, 1.5)
# [INFO]   Call site 2: CALL set_data(data_array, n, 1.0, 1.5)
# [INFO] The procedure type is subroutine.
# [INFO]  No nested procedures found in 'set_data' - proceeding to complete isolation
# [INFO] Induced INTENT for subroutine 'set_data':
# [INFO]   'arr': 'OUT'
# [INFO]   'size': 'IN'
# [INFO]   'start': 'IN'
# [INFO]   'step': 'IN'
# [INFO] 📁 Created parent function directory: /home/kardaneh/Fgpt/example_01/set_data
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Processing initialization completed!
# [INFO] Processing initialization completed!
# [INFO] Declarations and allocations processed successfully
# [INFO] Successfully parsed string!
# [INFO] Successfully parsed module code
# [INFO] Successfully parsed main program code
# [INFO] Inserted I/O statements at beginning of Execution_Part in procedure: set_data
# [INFO] Successfully updated the global module
# [INFO] Successfully wrote code to file: /home/kardaneh/Fgpt/example_01/set_data/module_global_set_data.f90
# [INFO] Allocatable declaration: REAL, ALLOCATABLE, DIMENSION(:) :: arr
# [INFO] Allocate statement: ALLOCATE(arr(size))
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Combined statement: REAL, DIMENSION(size) :: arr
# [INFO] Successfully parsed statement: IF (.NOT. ALLOCATED(arr)) THEN
#   ALLOCATE(arr(size))
# END IF
# [INFO] Successfully generated allocation statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully parsed statement: READ(1363, IOSTAT = ier) size
# IF (ier /= 0) THEN
#   WRITE(*, *) 'Error reading from file for size. ', ' IOSTAT : ', ier
# END IF
# [INFO] Successfully parsed statement: READ(1363, IOSTAT = ier) start
# IF (ier /= 0) THEN
#   WRITE(*, *) 'Error reading from file for start. ', ' IOSTAT : ', ier
# END IF
# [INFO] Successfully parsed statement: READ(1363, IOSTAT = ier) step
# IF (ier /= 0) THEN
#   WRITE(*, *) 'Error reading from file for step. ', ' IOSTAT : ', ier
# END IF
# [INFO] Processing initialization completed!
# [INFO] Successfully parsed statement: READ(1363, IOSTAT = ier) arr
# IF (ier /= 0) THEN
#   WRITE(*, *) 'Error reading from file for arr. ', ' IOSTAT : ', ier
# END IF
# [INFO] Processing initialization completed!
# [INFO] Declarations and allocations processed successfully
# [INFO] Inserted I/O statements at beginning of Execution_Part in procedure: set_data
# [INFO] Successfully parsed statement: CALL SYSTEM_CLOCK(ic0, icr, ic)
# start_time = ic0 * 1.0 / icr
# [INFO] Successfully parsed statement: CALL SYSTEM_CLOCK(ic0, icr, ic)
# stop_time = ic0 * 1.0 / icr
# WRITE(*, *) "Execution time : ", stop_time - start_time
# OPEN(UNIT = 1363, FILE = '/home/kardaneh/Fgpt/benchmark/set_data/time.txt', STATUS = 'unknown', POSITION =
# 'append')
# WRITE(1363, *) stop_time - start_time
# CLOSE(UNIT = 1363)
# [INFO] Successfully parsed statement: OPEN(UNIT = 1363, FILE = '/home/kardaneh/Fgpt/benchmark/set_data/output.bin',
# FORM = 'unformatted', STATUS = 'replace')
# WRITE(1363) arr
# CLOSE(UNIT = 1363)
# [INFO] Successfully updated the main program
# [INFO] Successfully wrote code to file: /home/kardaneh/Fgpt/example_01/set_data/main_set_data.f90
# [INFO] Compiling and running in /home/kardaneh/Fgpt/example_01/set_data...
# Tapenade files detected (adjoint: , tangent: ) - enabling Tapenade runtime
# rm -rf obj set_data mod /home/kardaneh/Fgpt/example_01/set_data/set_data.txt
# Cleaned build artifacts.
# Tapenade files detected (adjoint: , tangent: ) - enabling Tapenade runtime
# rm -rf obj set_data mod /home/kardaneh/Fgpt/example_01/set_data/set_data.txt
# Cleaned build artifacts.
# mpif90 -Wall -g -O0 -Kieee -Ktrap=fp -Mbounds -traceback -r8 -i4 -I/data/ssivanes/modipsl_truck_opt/modeles/IOIPSL/inc -I/data/ssivanes/modipsl_truck_opt/modeles/XIOS/inc -I/data/ssivanes/modipsl_truck_opt/modeles/ORCHIDEE/inc -I/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-c/4.7.4-nvhpc-21.9-3ljfhvpzxouhzpusyuu6s5alubl5el7p/include -I/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-fortran/4.5.3-nvhpc-21.9-nf3dmves2qwgafsadgnawv45fiecf5ss/include -c /home/kardaneh/Fgpt/example_01/set_data/module_global_set_data.f90 -o obj/module_global_set_data.o -module mod >> /home/kardaneh/Fgpt/example_01/set_data/set_data.txt 2>&1
# mpif90 -Wall -g -O0 -Kieee -Ktrap=fp -Mbounds -traceback -r8 -i4 -I/data/ssivanes/modipsl_truck_opt/modeles/IOIPSL/inc -I/data/ssivanes/modipsl_truck_opt/modeles/XIOS/inc -I/data/ssivanes/modipsl_truck_opt/modeles/ORCHIDEE/inc -I/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-c/4.7.4-nvhpc-21.9-3ljfhvpzxouhzpusyuu6s5alubl5el7p/include -I/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-fortran/4.5.3-nvhpc-21.9-nf3dmves2qwgafsadgnawv45fiecf5ss/include -c /home/kardaneh/Fgpt/example_01/set_data/main_set_data.f90 -o obj/main_set_data.o -module mod >> /home/kardaneh/Fgpt/example_01/set_data/set_data.txt 2>&1
# mpicc -Wall -g -O0 -Kieee -Ktrap=fp -traceback -DUNDERSCORE -fopenmp -c /data/kardaneh/tapenade/tapenade_3.16/ADFirstAidKit/adStack.c -o obj/adStack.o >> /home/kardaneh/Fgpt/example_01/set_data/set_data.txt 2>&1
# Linking set_data ...
# Including Tapenade object files for automatic differentiation.
# mpif90 -Wall -g -O0 -Kieee -Ktrap=fp -Mbounds -traceback -r8 -i4 obj/module_global_set_data.o obj/main_set_data.o obj/adStack.o -L/data/ssivanes/modipsl_truck_opt/modeles/ORCHIDEE/lib -lorchidee -L/data/ssivanes/modipsl_truck_opt/modeles/IOIPSL/lib -lioipsl -L/data/ssivanes/modipsl_truck_opt/modeles/XIOS/lib -lxios -lstdc++ -L/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-c/4.7.4-nvhpc-21.9-3ljfhvpzxouhzpusyuu6s5alubl5el7p/lib -lnetcdf -L/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-fortran/4.5.3-nvhpc-21.9-nf3dmves2qwgafsadgnawv45fiecf5ss/lib -lnetcdff -o set_data >> /home/kardaneh/Fgpt/example_01/set_data/set_data.txt 2>&1
# Build complete: set_data
# [INFO] Compilation process completed!
# [INFO] Benchmark files exist. Now running the unit tests ...
#  --- inside the main program ---
#  --- inside the declaration_initialization routine for set_data ---
#  --- inside the read_dummy routine for set_data ---
#  Data set successfully! start=    1.000000000000000       step=
#     1.500000000000000
#  Execution time :    1.9000000000000001E-005
# [INFO] Execution completed in /home/kardaneh/Fgpt/example_01/set_data
# [INFO] Successfully wrote code to file: /home/kardaneh/Fgpt/examples/example_01.f90
# ╭─────────────────────────────────────────────── ✅ Node Complete ────────────────────────────────────────────────╮
# │ Exiting node: Isolated Procedure                                                                                │
# │ Duration: 1.06s                                                                                                 │
# │ ✅ Done isolating → set_data                                                                                    │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# [INFO]    3. display_data
# [INFO] 🔄 Call recursively for 'display_data' from parent 'test_procedures'
# ╭───────────────────────────────────────────────── 🚀 Node Start ─────────────────────────────────────────────────╮
# │ 🧬 Entering node: Isolated Procedure                                                                            │
# │ 🔹 Parent → Child: test_procedures → display_data                                                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# [INFO]   Call site 1: CALL display_data(data_array, n, "Initial data display")
# [INFO]   Call site 2: CALL display_data(data_array, n, "After process_data (2*x)")
# [INFO]   Call site 3: CALL display_data(data_array, n, "After scale_data (0.5*x)")
# [INFO]   Call site 4: CALL display_data(data_array, n, "Pass 2: custom sequence")
# [INFO]   Call site 5: CALL display_data(data_array, n, "Pass 2: squared")
# [INFO]   Call site 6: CALL display_data(data_array, n, "Pass 2: scaled by 2 + 1")
# [INFO]   Call site 7: CALL display_data(data_array, n, "Pass 3: partial reset to 9.0")
# [INFO]   Call site 8: CALL display_data(data_array, n, "Final: full reset to 0.0")
# [INFO] The procedure type is subroutine.
# [INFO] Separated type declaration with 3 entities into 3 individual declarations
# [INFO]  No nested procedures found in 'display_data' - proceeding to complete isolation
# [INFO] Induced INTENT for subroutine 'display_data':
# [INFO]   'arr': 'IN'
# [INFO]   'size': 'IN'
# [INFO]   'label': 'IN'
# [INFO] 📁 Created parent function directory: /home/kardaneh/Fgpt/example_01/display_data
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Processing initialization completed!
# [INFO] Processing initialization completed!
# [INFO] Declarations and allocations processed successfully
# [INFO] Successfully parsed string!
# [INFO] Successfully parsed module code
# [INFO] Successfully parsed main program code
# [INFO] Inserted I/O statements at beginning of Execution_Part in procedure: display_data
# [INFO] Successfully updated the global module
# [INFO] Successfully wrote code to file: /home/kardaneh/Fgpt/example_01/display_data/module_global_display_data.f90
# [INFO] Allocatable declaration: REAL, ALLOCATABLE, DIMENSION(:) :: arr
# [INFO] Allocate statement: ALLOCATE(arr(size))
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Combined statement: REAL, DIMENSION(size) :: arr
# [INFO] Successfully parsed statement: IF (.NOT. ALLOCATED(arr)) THEN
#   ALLOCATE(arr(size))
# END IF
# [INFO] Successfully generated allocation statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully parsed statement: READ(1363, IOSTAT = ier) label
# IF (ier /= 0) THEN
#   WRITE(*, *) 'Error reading from file for label. ', ' IOSTAT : ', ier
# END IF
# [INFO] Successfully parsed statement: READ(1363, IOSTAT = ier) size
# IF (ier /= 0) THEN
#   WRITE(*, *) 'Error reading from file for size. ', ' IOSTAT : ', ier
# END IF
# [INFO] Processing initialization completed!
# [INFO] Successfully parsed statement: READ(1363, IOSTAT = ier) arr
# IF (ier /= 0) THEN
#   WRITE(*, *) 'Error reading from file for arr. ', ' IOSTAT : ', ier
# END IF
# [INFO] Processing initialization completed!
# [INFO] Declarations and allocations processed successfully
# [INFO] Inserted I/O statements at beginning of Execution_Part in procedure: display_data
# [INFO] Successfully parsed statement: CALL SYSTEM_CLOCK(ic0, icr, ic)
# start_time = ic0 * 1.0 / icr
# [INFO] Successfully parsed statement: CALL SYSTEM_CLOCK(ic0, icr, ic)
# stop_time = ic0 * 1.0 / icr
# WRITE(*, *) "Execution time : ", stop_time - start_time
# OPEN(UNIT = 1363, FILE = '/home/kardaneh/Fgpt/benchmark/display_data/time.txt', STATUS = 'unknown', POSITION =
# 'append')
# WRITE(1363, *) stop_time - start_time
# CLOSE(UNIT = 1363)
# [INFO] Successfully parsed statement: OPEN(UNIT = 1363, FILE =
# '/home/kardaneh/Fgpt/benchmark/display_data/output.bin', FORM = 'unformatted', STATUS = 'replace')
# CLOSE(UNIT = 1363)
# [INFO] Successfully updated the main program
# [INFO] Successfully wrote code to file: /home/kardaneh/Fgpt/example_01/display_data/main_display_data.f90
# [INFO] Compiling and running in /home/kardaneh/Fgpt/example_01/display_data...
# Tapenade files detected (adjoint: , tangent: ) - enabling Tapenade runtime
# rm -rf obj display_data mod /home/kardaneh/Fgpt/example_01/display_data/display_data.txt
# Cleaned build artifacts.
# Tapenade files detected (adjoint: , tangent: ) - enabling Tapenade runtime
# rm -rf obj display_data mod /home/kardaneh/Fgpt/example_01/display_data/display_data.txt
# Cleaned build artifacts.
# mpif90 -Wall -g -O0 -Kieee -Ktrap=fp -Mbounds -traceback -r8 -i4 -I/data/ssivanes/modipsl_truck_opt/modeles/IOIPSL/inc -I/data/ssivanes/modipsl_truck_opt/modeles/XIOS/inc -I/data/ssivanes/modipsl_truck_opt/modeles/ORCHIDEE/inc -I/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-c/4.7.4-nvhpc-21.9-3ljfhvpzxouhzpusyuu6s5alubl5el7p/include -I/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-fortran/4.5.3-nvhpc-21.9-nf3dmves2qwgafsadgnawv45fiecf5ss/include -c /home/kardaneh/Fgpt/example_01/display_data/module_global_display_data.f90 -o obj/module_global_display_data.o -module mod >> /home/kardaneh/Fgpt/example_01/display_data/display_data.txt 2>&1
# mpif90 -Wall -g -O0 -Kieee -Ktrap=fp -Mbounds -traceback -r8 -i4 -I/data/ssivanes/modipsl_truck_opt/modeles/IOIPSL/inc -I/data/ssivanes/modipsl_truck_opt/modeles/XIOS/inc -I/data/ssivanes/modipsl_truck_opt/modeles/ORCHIDEE/inc -I/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-c/4.7.4-nvhpc-21.9-3ljfhvpzxouhzpusyuu6s5alubl5el7p/include -I/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-fortran/4.5.3-nvhpc-21.9-nf3dmves2qwgafsadgnawv45fiecf5ss/include -c /home/kardaneh/Fgpt/example_01/display_data/main_display_data.f90 -o obj/main_display_data.o -module mod >> /home/kardaneh/Fgpt/example_01/display_data/display_data.txt 2>&1
# mpicc -Wall -g -O0 -Kieee -Ktrap=fp -traceback -DUNDERSCORE -fopenmp -c /data/kardaneh/tapenade/tapenade_3.16/ADFirstAidKit/adStack.c -o obj/adStack.o >> /home/kardaneh/Fgpt/example_01/display_data/display_data.txt 2>&1
# Linking display_data ...
# Including Tapenade object files for automatic differentiation.
# mpif90 -Wall -g -O0 -Kieee -Ktrap=fp -Mbounds -traceback -r8 -i4 obj/module_global_display_data.o obj/main_display_data.o obj/adStack.o -L/data/ssivanes/modipsl_truck_opt/modeles/ORCHIDEE/lib -lorchidee -L/data/ssivanes/modipsl_truck_opt/modeles/IOIPSL/lib -lioipsl -L/data/ssivanes/modipsl_truck_opt/modeles/XIOS/lib -lxios -lstdc++ -L/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-c/4.7.4-nvhpc-21.9-3ljfhvpzxouhzpusyuu6s5alubl5el7p/lib -lnetcdf -L/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-fortran/4.5.3-nvhpc-21.9-nf3dmves2qwgafsadgnawv45fiecf5ss/lib -lnetcdff -o display_data >> /home/kardaneh/Fgpt/example_01/display_data/display_data.txt 2>&1
# Build complete: display_data
# [INFO] Compilation process completed!
# [INFO] Benchmark files exist. Now running the unit tests ...
#  --- inside the main program ---
#  --- inside the declaration_initialization routine for display_data ---
#  --- inside the read_dummy routine for display_data ---
#  Error reading from file for label.  IOSTAT :           219
#
#   Element             1  :     0.000000000000000
#   Element             2  :     0.000000000000000
#   Element             3  :    0.1000000000000000
#   Element             4  :    0.1000000000000000
#   Element             5  :    0.1000000000000000
#   Element             6  :     0.000000000000000
#   Element             7  :     0.000000000000000
#   Element             8  :     0.000000000000000
#   Element             9  :     0.000000000000000
#   Element            10  :     0.000000000000000
#     min =     0.000000000000000
#     max =    0.1000000000000000
#     sum =    0.3000000000000000
#  Execution time :    5.1999999999999997E-005
# [INFO] Execution completed in /home/kardaneh/Fgpt/example_01/display_data
# [INFO] Successfully wrote code to file: /home/kardaneh/Fgpt/examples/example_01.f90
# ╭─────────────────────────────────────────────── ✅ Node Complete ────────────────────────────────────────────────╮
# │ Exiting node: Isolated Procedure                                                                                │
# │ Duration: 1.00s                                                                                                 │
# │ ✅ Done isolating → display_data                                                                                │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# [INFO]    4. process_data
# [INFO] 🔄 Call recursively for 'process_data' from parent 'test_procedures'
# ╭───────────────────────────────────────────────── 🚀 Node Start ─────────────────────────────────────────────────╮
# │ 🧬 Entering node: Isolated Procedure                                                                            │
# │ 🔹 Parent → Child: test_procedures → process_data                                                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# [INFO]   Call site 1: CALL process_data(data_array, n, 0.0, 2.0, 0.0)
# [INFO]   Call site 2: CALL process_data(data_array, n, 1.0, 0.0, 0.0)
# [INFO] The procedure type is subroutine.
# [INFO] Separated type declaration with 3 entities into 3 individual declarations
# [INFO]  No nested procedures found in 'process_data' - proceeding to complete isolation
# [INFO] Induced INTENT for subroutine 'process_data':
# [INFO]   'arr': 'INOUT'
# [INFO]   'size': 'IN'
# [INFO]   'a': 'IN'
# [INFO]   'b': 'IN'
# [INFO]   'c': 'IN'
# [INFO] 📁 Created parent function directory: /home/kardaneh/Fgpt/example_01/process_data
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Processing initialization completed!
# [INFO] Processing initialization completed!
# [INFO] Declarations and allocations processed successfully
# [INFO] Successfully parsed string!
# [INFO] Successfully parsed module code
# [INFO] Successfully parsed main program code
# [INFO] Inserted I/O statements at beginning of Execution_Part in procedure: process_data
# [INFO] Successfully updated the global module
# [INFO] Successfully wrote code to file: /home/kardaneh/Fgpt/example_01/process_data/module_global_process_data.f90
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Allocatable declaration: REAL, ALLOCATABLE, DIMENSION(:) :: arr
# [INFO] Allocate statement: ALLOCATE(arr(size))
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Combined statement: REAL, DIMENSION(size) :: arr
# [INFO] Successfully parsed statement: IF (.NOT. ALLOCATED(arr)) THEN
#   ALLOCATE(arr(size))
# END IF
# [INFO] Successfully generated allocation statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully parsed statement: READ(1363, IOSTAT = ier) a
# IF (ier /= 0) THEN
#   WRITE(*, *) 'Error reading from file for a. ', ' IOSTAT : ', ier
# END IF
# [INFO] Successfully parsed statement: READ(1363, IOSTAT = ier) b
# IF (ier /= 0) THEN
#   WRITE(*, *) 'Error reading from file for b. ', ' IOSTAT : ', ier
# END IF
# [INFO] Successfully parsed statement: READ(1363, IOSTAT = ier) c
# IF (ier /= 0) THEN
#   WRITE(*, *) 'Error reading from file for c. ', ' IOSTAT : ', ier
# END IF
# [INFO] Successfully parsed statement: READ(1363, IOSTAT = ier) size
# IF (ier /= 0) THEN
#   WRITE(*, *) 'Error reading from file for size. ', ' IOSTAT : ', ier
# END IF
# [INFO] Processing initialization completed!
# [INFO] Successfully parsed statement: READ(1363, IOSTAT = ier) arr
# IF (ier /= 0) THEN
#   WRITE(*, *) 'Error reading from file for arr. ', ' IOSTAT : ', ier
# END IF
# [INFO] Processing initialization completed!
# [INFO] Declarations and allocations processed successfully
# [INFO] Inserted I/O statements at beginning of Execution_Part in procedure: process_data
# [INFO] Successfully parsed statement: CALL SYSTEM_CLOCK(ic0, icr, ic)
# start_time = ic0 * 1.0 / icr
# [INFO] Successfully parsed statement: CALL SYSTEM_CLOCK(ic0, icr, ic)
# stop_time = ic0 * 1.0 / icr
# WRITE(*, *) "Execution time : ", stop_time - start_time
# OPEN(UNIT = 1363, FILE = '/home/kardaneh/Fgpt/benchmark/process_data/time.txt', STATUS = 'unknown', POSITION =
# 'append')
# WRITE(1363, *) stop_time - start_time
# CLOSE(UNIT = 1363)
# [INFO] Successfully parsed statement: OPEN(UNIT = 1363, FILE =
# '/home/kardaneh/Fgpt/benchmark/process_data/output.bin', FORM = 'unformatted', STATUS = 'replace')
# WRITE(1363) arr
# CLOSE(UNIT = 1363)
# [INFO] Successfully updated the main program
# [INFO] Successfully wrote code to file: /home/kardaneh/Fgpt/example_01/process_data/main_process_data.f90
# [INFO] Compiling and running in /home/kardaneh/Fgpt/example_01/process_data...
# Tapenade files detected (adjoint: , tangent: ) - enabling Tapenade runtime
# rm -rf obj process_data mod /home/kardaneh/Fgpt/example_01/process_data/process_data.txt
# Cleaned build artifacts.
# Tapenade files detected (adjoint: , tangent: ) - enabling Tapenade runtime
# rm -rf obj process_data mod /home/kardaneh/Fgpt/example_01/process_data/process_data.txt
# Cleaned build artifacts.
# mpif90 -Wall -g -O0 -Kieee -Ktrap=fp -Mbounds -traceback -r8 -i4 -I/data/ssivanes/modipsl_truck_opt/modeles/IOIPSL/inc -I/data/ssivanes/modipsl_truck_opt/modeles/XIOS/inc -I/data/ssivanes/modipsl_truck_opt/modeles/ORCHIDEE/inc -I/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-c/4.7.4-nvhpc-21.9-3ljfhvpzxouhzpusyuu6s5alubl5el7p/include -I/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-fortran/4.5.3-nvhpc-21.9-nf3dmves2qwgafsadgnawv45fiecf5ss/include -c /home/kardaneh/Fgpt/example_01/process_data/module_global_process_data.f90 -o obj/module_global_process_data.o -module mod >> /home/kardaneh/Fgpt/example_01/process_data/process_data.txt 2>&1
# mpif90 -Wall -g -O0 -Kieee -Ktrap=fp -Mbounds -traceback -r8 -i4 -I/data/ssivanes/modipsl_truck_opt/modeles/IOIPSL/inc -I/data/ssivanes/modipsl_truck_opt/modeles/XIOS/inc -I/data/ssivanes/modipsl_truck_opt/modeles/ORCHIDEE/inc -I/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-c/4.7.4-nvhpc-21.9-3ljfhvpzxouhzpusyuu6s5alubl5el7p/include -I/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-fortran/4.5.3-nvhpc-21.9-nf3dmves2qwgafsadgnawv45fiecf5ss/include -c /home/kardaneh/Fgpt/example_01/process_data/main_process_data.f90 -o obj/main_process_data.o -module mod >> /home/kardaneh/Fgpt/example_01/process_data/process_data.txt 2>&1
# mpicc -Wall -g -O0 -Kieee -Ktrap=fp -traceback -DUNDERSCORE -fopenmp -c /data/kardaneh/tapenade/tapenade_3.16/ADFirstAidKit/adStack.c -o obj/adStack.o >> /home/kardaneh/Fgpt/example_01/process_data/process_data.txt 2>&1
# Linking process_data ...
# Including Tapenade object files for automatic differentiation.
# mpif90 -Wall -g -O0 -Kieee -Ktrap=fp -Mbounds -traceback -r8 -i4 obj/module_global_process_data.o obj/main_process_data.o obj/adStack.o -L/data/ssivanes/modipsl_truck_opt/modeles/ORCHIDEE/lib -lorchidee -L/data/ssivanes/modipsl_truck_opt/modeles/IOIPSL/lib -lioipsl -L/data/ssivanes/modipsl_truck_opt/modeles/XIOS/lib -lxios -lstdc++ -L/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-c/4.7.4-nvhpc-21.9-3ljfhvpzxouhzpusyuu6s5alubl5el7p/lib -lnetcdf -L/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-fortran/4.5.3-nvhpc-21.9-nf3dmves2qwgafsadgnawv45fiecf5ss/lib -lnetcdff -o process_data >> /home/kardaneh/Fgpt/example_01/process_data/process_data.txt 2>&1
# Build complete: process_data
# [INFO] Compilation process completed!
# [INFO] Benchmark files exist. Now running the unit tests ...
#  --- inside the main program ---
#  --- inside the declaration_initialization routine for process_data ---
#  --- inside the read_dummy routine for process_data ---
#  Data processed successfully! a=    1.000000000000000       b=
#     0.000000000000000       c=    0.000000000000000
#  Execution time :    3.8000000000000002E-005
# [INFO] Execution completed in /home/kardaneh/Fgpt/example_01/process_data
# [INFO] Successfully wrote code to file: /home/kardaneh/Fgpt/examples/example_01.f90
# ╭─────────────────────────────────────────────── ✅ Node Complete ────────────────────────────────────────────────╮
# │ Exiting node: Isolated Procedure                                                                                │
# │ Duration: 0.98s                                                                                                 │
# │ ✅ Done isolating → process_data                                                                                │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# [INFO]    5. scale_data
# [INFO] 🔄 Call recursively for 'scale_data' from parent 'test_procedures'
# ╭───────────────────────────────────────────────── 🚀 Node Start ─────────────────────────────────────────────────╮
# │ 🧬 Entering node: Isolated Procedure                                                                            │
# │ 🔹 Parent → Child: test_procedures → scale_data                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# [INFO]   Call site 1: CALL scale_data(data_array, n, 0.5, 0.0)
# [INFO]   Call site 2: CALL scale_data(data_array, n, 2.0, 1.0)
# [INFO] The procedure type is subroutine.
# [INFO]  No nested procedures found in 'scale_data' - proceeding to complete isolation
# [INFO] Induced INTENT for subroutine 'scale_data':
# [INFO]   'arr': 'INOUT'
# [INFO]   'size': 'IN'
# [INFO]   'factor': 'IN'
# [INFO]   'offset': 'IN'
# [INFO] 📁 Created parent function directory: /home/kardaneh/Fgpt/example_01/scale_data
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Processing initialization completed!
# [INFO] Processing initialization completed!
# [INFO] Declarations and allocations processed successfully
# [INFO] Successfully parsed string!
# [INFO] Successfully parsed module code
# [INFO] Successfully parsed main program code
# [INFO] Inserted I/O statements at beginning of Execution_Part in procedure: scale_data
# [INFO] Successfully updated the global module
# [INFO] Successfully wrote code to file: /home/kardaneh/Fgpt/example_01/scale_data/module_global_scale_data.f90
# [INFO] Allocatable declaration: REAL, ALLOCATABLE, DIMENSION(:) :: arr
# [INFO] Allocate statement: ALLOCATE(arr(size))
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Combined statement: REAL, DIMENSION(size) :: arr
# [INFO] Successfully parsed statement: IF (.NOT. ALLOCATED(arr)) THEN
#   ALLOCATE(arr(size))
# END IF
# [INFO] Successfully generated allocation statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully parsed statement: READ(1363, IOSTAT = ier) factor
# IF (ier /= 0) THEN
#   WRITE(*, *) 'Error reading from file for factor. ', ' IOSTAT : ', ier
# END IF
# [INFO] Successfully parsed statement: READ(1363, IOSTAT = ier) offset
# IF (ier /= 0) THEN
#   WRITE(*, *) 'Error reading from file for offset. ', ' IOSTAT : ', ier
# END IF
# [INFO] Successfully parsed statement: READ(1363, IOSTAT = ier) size
# IF (ier /= 0) THEN
#   WRITE(*, *) 'Error reading from file for size. ', ' IOSTAT : ', ier
# END IF
# [INFO] Processing initialization completed!
# [INFO] Successfully parsed statement: READ(1363, IOSTAT = ier) arr
# IF (ier /= 0) THEN
#   WRITE(*, *) 'Error reading from file for arr. ', ' IOSTAT : ', ier
# END IF
# [INFO] Processing initialization completed!
# [INFO] Declarations and allocations processed successfully
# [INFO] Inserted I/O statements at beginning of Execution_Part in procedure: scale_data
# [INFO] Successfully parsed statement: CALL SYSTEM_CLOCK(ic0, icr, ic)
# start_time = ic0 * 1.0 / icr
# [INFO] Successfully parsed statement: CALL SYSTEM_CLOCK(ic0, icr, ic)
# stop_time = ic0 * 1.0 / icr
# WRITE(*, *) "Execution time : ", stop_time - start_time
# OPEN(UNIT = 1363, FILE = '/home/kardaneh/Fgpt/benchmark/scale_data/time.txt', STATUS = 'unknown', POSITION =
# 'append')
# WRITE(1363, *) stop_time - start_time
# CLOSE(UNIT = 1363)
# [INFO] Successfully parsed statement: OPEN(UNIT = 1363, FILE =
# '/home/kardaneh/Fgpt/benchmark/scale_data/output.bin', FORM = 'unformatted', STATUS = 'replace')
# WRITE(1363) arr
# CLOSE(UNIT = 1363)
# [INFO] Successfully updated the main program
# [INFO] Successfully wrote code to file: /home/kardaneh/Fgpt/example_01/scale_data/main_scale_data.f90
# [INFO] Compiling and running in /home/kardaneh/Fgpt/example_01/scale_data...
# Tapenade files detected (adjoint: , tangent: ) - enabling Tapenade runtime
# rm -rf obj scale_data mod /home/kardaneh/Fgpt/example_01/scale_data/scale_data.txt
# Cleaned build artifacts.
# Tapenade files detected (adjoint: , tangent: ) - enabling Tapenade runtime
# rm -rf obj scale_data mod /home/kardaneh/Fgpt/example_01/scale_data/scale_data.txt
# Cleaned build artifacts.
# mpif90 -Wall -g -O0 -Kieee -Ktrap=fp -Mbounds -traceback -r8 -i4 -I/data/ssivanes/modipsl_truck_opt/modeles/IOIPSL/inc -I/data/ssivanes/modipsl_truck_opt/modeles/XIOS/inc -I/data/ssivanes/modipsl_truck_opt/modeles/ORCHIDEE/inc -I/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-c/4.7.4-nvhpc-21.9-3ljfhvpzxouhzpusyuu6s5alubl5el7p/include -I/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-fortran/4.5.3-nvhpc-21.9-nf3dmves2qwgafsadgnawv45fiecf5ss/include -c /home/kardaneh/Fgpt/example_01/scale_data/module_global_scale_data.f90 -o obj/module_global_scale_data.o -module mod >> /home/kardaneh/Fgpt/example_01/scale_data/scale_data.txt 2>&1
# mpif90 -Wall -g -O0 -Kieee -Ktrap=fp -Mbounds -traceback -r8 -i4 -I/data/ssivanes/modipsl_truck_opt/modeles/IOIPSL/inc -I/data/ssivanes/modipsl_truck_opt/modeles/XIOS/inc -I/data/ssivanes/modipsl_truck_opt/modeles/ORCHIDEE/inc -I/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-c/4.7.4-nvhpc-21.9-3ljfhvpzxouhzpusyuu6s5alubl5el7p/include -I/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-fortran/4.5.3-nvhpc-21.9-nf3dmves2qwgafsadgnawv45fiecf5ss/include -c /home/kardaneh/Fgpt/example_01/scale_data/main_scale_data.f90 -o obj/main_scale_data.o -module mod >> /home/kardaneh/Fgpt/example_01/scale_data/scale_data.txt 2>&1
# mpicc -Wall -g -O0 -Kieee -Ktrap=fp -traceback -DUNDERSCORE -fopenmp -c /data/kardaneh/tapenade/tapenade_3.16/ADFirstAidKit/adStack.c -o obj/adStack.o >> /home/kardaneh/Fgpt/example_01/scale_data/scale_data.txt 2>&1
# Linking scale_data ...
# Including Tapenade object files for automatic differentiation.
# mpif90 -Wall -g -O0 -Kieee -Ktrap=fp -Mbounds -traceback -r8 -i4 obj/module_global_scale_data.o obj/main_scale_data.o obj/adStack.o -L/data/ssivanes/modipsl_truck_opt/modeles/ORCHIDEE/lib -lorchidee -L/data/ssivanes/modipsl_truck_opt/modeles/IOIPSL/lib -lioipsl -L/data/ssivanes/modipsl_truck_opt/modeles/XIOS/lib -lxios -lstdc++ -L/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-c/4.7.4-nvhpc-21.9-3ljfhvpzxouhzpusyuu6s5alubl5el7p/lib -lnetcdf -L/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-fortran/4.5.3-nvhpc-21.9-nf3dmves2qwgafsadgnawv45fiecf5ss/lib -lnetcdff -o scale_data >> /home/kardaneh/Fgpt/example_01/scale_data/scale_data.txt 2>&1
# Build complete: scale_data
# [INFO] Compilation process completed!
# [INFO] Benchmark files exist. Now running the unit tests ...
#  --- inside the main program ---
#  --- inside the declaration_initialization routine for scale_data ---
#  --- inside the read_dummy routine for scale_data ---
#  Data scaled by factor:     2.000000000000000       offset:
#     1.000000000000000
#  Execution time :    2.5000000000000001E-005
# [INFO] Execution completed in /home/kardaneh/Fgpt/example_01/scale_data
# [INFO] Successfully wrote code to file: /home/kardaneh/Fgpt/examples/example_01.f90
# ╭─────────────────────────────────────────────── ✅ Node Complete ────────────────────────────────────────────────╮
# │ Exiting node: Isolated Procedure                                                                                │
# │ Duration: 0.98s                                                                                                 │
# │ ✅ Done isolating → scale_data                                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# [INFO]    6. dump_to_file
# [INFO] 🔄 Call recursively for 'dump_to_file' from parent 'test_procedures'
# ╭───────────────────────────────────────────────── 🚀 Node Start ─────────────────────────────────────────────────╮
# │ 🧬 Entering node: Isolated Procedure                                                                            │
# │ 🔹 Parent → Child: test_procedures → dump_to_file                                                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# [INFO]   Call site 1: CALL dump_to_file(data_array, n, "output_data.txt")
# [INFO]   Call site 2: CALL dump_to_file(data_array, n, "output_rst.txt")
# [INFO] The procedure type is subroutine.
# [INFO] Separated type declaration with 3 entities into 3 individual declarations
# [INFO]  No nested procedures found in 'dump_to_file' - proceeding to complete isolation
# [INFO] Induced INTENT for subroutine 'dump_to_file':
# [INFO]   'arr': 'IN'
# [INFO]   'size': 'IN'
# [INFO]   'filename': 'IN'
# [INFO] 📁 Created parent function directory: /home/kardaneh/Fgpt/example_01/dump_to_file
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Processing initialization completed!
# [INFO] Processing initialization completed!
# [INFO] Declarations and allocations processed successfully
# [INFO] Successfully parsed string!
# [INFO] Successfully parsed module code
# [INFO] Successfully parsed main program code
# [INFO] Inserted I/O statements at beginning of Execution_Part in procedure: dump_to_file
# [INFO] Successfully updated the global module
# [INFO] Successfully wrote code to file: /home/kardaneh/Fgpt/example_01/dump_to_file/module_global_dump_to_file.f90
# [INFO] Allocatable declaration: REAL, ALLOCATABLE, DIMENSION(:) :: arr
# [INFO] Allocate statement: ALLOCATE(arr(size))
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Combined statement: REAL, DIMENSION(size) :: arr
# [INFO] Successfully parsed statement: IF (.NOT. ALLOCATED(arr)) THEN
#   ALLOCATE(arr(size))
# END IF
# [INFO] Successfully generated allocation statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully parsed statement: READ(1363, IOSTAT = ier) filename
# IF (ier /= 0) THEN
#   WRITE(*, *) 'Error reading from file for filename. ', ' IOSTAT : ', ier
# END IF
# [INFO] Successfully parsed statement: READ(1363, IOSTAT = ier) size
# IF (ier /= 0) THEN
#   WRITE(*, *) 'Error reading from file for size. ', ' IOSTAT : ', ier
# END IF
# [INFO] Processing initialization completed!
# [INFO] Successfully parsed statement: READ(1363, IOSTAT = ier) arr
# IF (ier /= 0) THEN
#   WRITE(*, *) 'Error reading from file for arr. ', ' IOSTAT : ', ier
# END IF
# [INFO] Processing initialization completed!
# [INFO] Declarations and allocations processed successfully
# [INFO] Inserted I/O statements at beginning of Execution_Part in procedure: dump_to_file
# [INFO] Successfully parsed statement: CALL SYSTEM_CLOCK(ic0, icr, ic)
# start_time = ic0 * 1.0 / icr
# [INFO] Successfully parsed statement: CALL SYSTEM_CLOCK(ic0, icr, ic)
# stop_time = ic0 * 1.0 / icr
# WRITE(*, *) "Execution time : ", stop_time - start_time
# OPEN(UNIT = 1363, FILE = '/home/kardaneh/Fgpt/benchmark/dump_to_file/time.txt', STATUS = 'unknown', POSITION =
# 'append')
# WRITE(1363, *) stop_time - start_time
# CLOSE(UNIT = 1363)
# [INFO] Successfully parsed statement: OPEN(UNIT = 1363, FILE =
# ...
# Build complete: dump_to_file
# [INFO] Compilation process completed!
# [INFO] Benchmark files exist. Now running the unit tests ...
#  --- inside the main program ---
#  --- inside the declaration_initialization routine for dump_to_file ---
#  --- inside the read_dummy routine for dump_to_file ---
#  Error reading from file for filename.  IOSTAT :           219
#  ERROR: could not open
#
#  Execution time :    2.0000000000000002E-005
# [INFO] Execution completed in /home/kardaneh/Fgpt/example_01/dump_to_file
# [INFO] Successfully wrote code to file: /home/kardaneh/Fgpt/examples/example_01.f90
# ╭─────────────────────────────────────────────── ✅ Node Complete ────────────────────────────────────────────────╮
# │ Exiting node: Isolated Procedure                                                                                │
# │ Duration: 1.00s                                                                                                 │
# │ ✅ Done isolating → dump_to_file                                                                                │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# [INFO]    7. reset_data
# [INFO] 🔄 Call recursively for 'reset_data' from parent 'test_procedures'
# ╭───────────────────────────────────────────────── 🚀 Node Start ─────────────────────────────────────────────────╮
# │ 🧬 Entering node: Isolated Procedure                                                                            │
# │ 🔹 Parent → Child: test_procedures → reset_data                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# [INFO]   Call site 1: CALL reset_data(data_array, n, 9.0, 2, 4)
# [INFO]   Call site 2: CALL reset_data(data_array, n, 0.1, 3, 5)
# [INFO] The procedure type is subroutine.
# [INFO] Separated type declaration with 2 entities into 2 individual declarations
# [INFO] Separated type declaration with 3 entities into 3 individual declarations
# [INFO]  No nested procedures found in 'reset_data' - proceeding to complete isolation
# [INFO] Induced INTENT for subroutine 'reset_data':
# [INFO]   'arr': 'OUT'
# [INFO]   'size': 'IN'
# [INFO]   'value': 'IN'
# [INFO]   'first': 'IN'
# [INFO]   'last': 'IN'
# [INFO] 📁 Created parent function directory: /home/kardaneh/Fgpt/example_01/reset_data
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Processing initialization completed!
# [INFO] Processing initialization completed!
# [INFO] Declarations and allocations processed successfully
# [INFO] Successfully parsed string!
# [INFO] Successfully parsed module code
# [INFO] Successfully parsed main program code
# [INFO] Inserted I/O statements at beginning of Execution_Part in procedure: reset_data
# [INFO] Successfully updated the global module
# [INFO] Successfully wrote code to file: /home/kardaneh/Fgpt/example_01/reset_data/module_global_reset_data.f90
# [INFO] Allocatable declaration: REAL, ALLOCATABLE, DIMENSION(:) :: arr
# [INFO] Allocate statement: ALLOCATE(arr(size))
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Combined statement: REAL, DIMENSION(size) :: arr
# [INFO] Successfully parsed statement: IF (.NOT. ALLOCATED(arr)) THEN
#   ALLOCATE(arr(size))
# END IF
# [INFO] Successfully generated allocation statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully parsed statement: READ(1363, IOSTAT = ier) first
# IF (ier /= 0) THEN
#   WRITE(*, *) 'Error reading from file for first. ', ' IOSTAT : ', ier
# END IF
# [INFO] Successfully parsed statement: READ(1363, IOSTAT = ier) last
# IF (ier /= 0) THEN
#   WRITE(*, *) 'Error reading from file for last. ', ' IOSTAT : ', ier
# END IF
# [INFO] Successfully parsed statement: READ(1363, IOSTAT = ier) size
# IF (ier /= 0) THEN
#   WRITE(*, *) 'Error reading from file for size. ', ' IOSTAT : ', ier
# END IF
# [INFO] Successfully parsed statement: READ(1363, IOSTAT = ier) value
# IF (ier /= 0) THEN
#   WRITE(*, *) 'Error reading from file for value. ', ' IOSTAT : ', ier
# END IF
# [INFO] Processing initialization completed!
# [INFO] Successfully parsed statement: READ(1363, IOSTAT = ier) arr
# IF (ier /= 0) THEN
#   WRITE(*, *) 'Error reading from file for arr. ', ' IOSTAT : ', ier
# END IF
# [INFO] Processing initialization completed!
# [INFO] Declarations and allocations processed successfully
# [INFO] Inserted I/O statements at beginning of Execution_Part in procedure: reset_data
# [INFO] Successfully parsed statement: CALL SYSTEM_CLOCK(ic0, icr, ic)
# start_time = ic0 * 1.0 / icr
# [INFO] Successfully parsed statement: CALL SYSTEM_CLOCK(ic0, icr, ic)
# stop_time = ic0 * 1.0 / icr
# WRITE(*, *) "Execution time : ", stop_time - start_time
# OPEN(UNIT = 1363, FILE = '/home/kardaneh/Fgpt/benchmark/reset_data/time.txt', STATUS = 'unknown', POSITION =
# 'append')
# WRITE(1363, *) stop_time - start_time
# CLOSE(UNIT = 1363)
# [INFO] Successfully parsed statement: OPEN(UNIT = 1363, FILE =
# '/home/kardaneh/Fgpt/benchmark/reset_data/output.bin', FORM = 'unformatted', STATUS = 'replace')
# WRITE(1363) arr
# CLOSE(UNIT = 1363)
# [INFO] Successfully updated the main program
# [INFO] Successfully wrote code to file: /home/kardaneh/Fgpt/example_01/reset_data/main_reset_data.f90
# [INFO] Compiling and running in /home/kardaneh/Fgpt/example_01/reset_data...
# Tapenade files detected (adjoint: , tangent: ) - enabling Tapenade runtime
# rm -rf obj reset_data mod /home/kardaneh/Fgpt/example_01/reset_data/reset_data.txt
# Cleaned build artifacts.
# Tapenade files detected (adjoint: , tangent: ) - enabling Tapenade runtime
# rm -rf obj reset_data mod /home/kardaneh/Fgpt/example_01/reset_data/reset_data.txt
# Cleaned build artifacts.
# mpif90 -Wall -g -O0 -Kieee -Ktrap=fp -Mbounds -traceback -r8 -i4 -I/data/ssivanes/modipsl_truck_opt/modeles/IOIPSL/inc -I/data/ssivanes/modipsl_truck_opt/modeles/XIOS/inc -I/data/ssivanes/modipsl_truck_opt/modeles/ORCHIDEE/inc -I/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-c/4.7.4-nvhpc-21.9-3ljfhvpzxouhzpusyuu6s5alubl5el7p/include -I/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-fortran/4.5.3-nvhpc-21.9-nf3dmves2qwgafsadgnawv45fiecf5ss/include -c /home/kardaneh/Fgpt/example_01/reset_data/module_global_reset_data.f90 -o obj/module_global_reset_data.o -module mod >> /home/kardaneh/Fgpt/example_01/reset_data/reset_data.txt 2>&1
# mpif90 -Wall -g -O0 -Kieee -Ktrap=fp -Mbounds -traceback -r8 -i4 -I/data/ssivanes/modipsl_truck_opt/modeles/IOIPSL/inc -I/data/ssivanes/modipsl_truck_opt/modeles/XIOS/inc -I/data/ssivanes/modipsl_truck_opt/modeles/ORCHIDEE/inc -I/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-c/4.7.4-nvhpc-21.9-3ljfhvpzxouhzpusyuu6s5alubl5el7p/include -I/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-fortran/4.5.3-nvhpc-21.9-nf3dmves2qwgafsadgnawv45fiecf5ss/include -c /home/kardaneh/Fgpt/example_01/reset_data/main_reset_data.f90 -o obj/main_reset_data.o -module mod >> /home/kardaneh/Fgpt/example_01/reset_data/reset_data.txt 2>&1
# mpicc -Wall -g -O0 -Kieee -Ktrap=fp -traceback -DUNDERSCORE -fopenmp -c /data/kardaneh/tapenade/tapenade_3.16/ADFirstAidKit/adStack.c -o obj/adStack.o >> /home/kardaneh/Fgpt/example_01/reset_data/reset_data.txt 2>&1
# Linking reset_data ...
# Including Tapenade object files for automatic differentiation.
# mpif90 -Wall -g -O0 -Kieee -Ktrap=fp -Mbounds -traceback -r8 -i4 obj/module_global_reset_data.o obj/main_reset_data.o obj/adStack.o -L/data/ssivanes/modipsl_truck_opt/modeles/ORCHIDEE/lib -lorchidee -L/data/ssivanes/modipsl_truck_opt/modeles/IOIPSL/lib -lioipsl -L/data/ssivanes/modipsl_truck_opt/modeles/XIOS/lib -lxios -lstdc++ -L/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-c/4.7.4-nvhpc-21.9-3ljfhvpzxouhzpusyuu6s5alubl5el7p/lib -lnetcdf -L/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-fortran/4.5.3-nvhpc-21.9-nf3dmves2qwgafsadgnawv45fiecf5ss/lib -lnetcdff -o reset_data >> /home/kardaneh/Fgpt/example_01/reset_data/reset_data.txt 2>&1
# Build complete: reset_data
# [INFO] Compilation process completed!
# [INFO] Benchmark files exist. Now running the unit tests ...
#  --- inside the main program ---
#  --- inside the declaration_initialization routine for reset_data ---
#  --- inside the read_dummy routine for reset_data ---
#  Data reset to    0.1000000000000000       over [            3 ,            5 ]
#  Execution time :    2.0000000000000002E-005
# [INFO] Execution completed in /home/kardaneh/Fgpt/example_01/reset_data
# [INFO] Successfully wrote code to file: /home/kardaneh/Fgpt/examples/example_01.f90
# ╭─────────────────────────────────────────────── ✅ Node Complete ────────────────────────────────────────────────╮
# │ Exiting node: Isolated Procedure                                                                                │
# │ Duration: 0.97s                                                                                                 │
# │ ✅ Done isolating → reset_data                                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# [INFO] Induced INTENT for subroutine 'test_procedures':
# [WARNING] ⚠ Removing declaration of function 'compute_average' from 'test_procedures' (now provided by the
# generated module).
# [INFO] 📁 Created parent function directory: /home/kardaneh/Fgpt/example_01/test_procedures
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Processing initialization completed!
# [INFO] Processing initialization completed!
# [INFO] Declarations and allocations processed successfully
# [INFO] Successfully parsed string!
# [WARNING] ⚠ The procedure test_procedures is a main_program, so not need to add it into global module.
# [INFO] Successfully parsed module code
# [INFO] Successfully parsed main program code
# [INFO] Inserted I/O statements at beginning of Execution_Part in procedure: test_procedures
# [INFO] Successfully updated the global module
# [INFO] Successfully wrote code to file:
# /home/kardaneh/Fgpt/example_01/test_procedures/module_global_test_procedures.f90
# [INFO] The procedure type is main_program. No need fro call statment!
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Successfully removed INTENT and SAVE attributes from statements
# [INFO] Processing initialization completed!
# [INFO] Processing initialization completed!
# [INFO] Declarations and allocations processed successfully
# [INFO] Inserted I/O statements at beginning of Execution_Part in procedure: test_procedures
# [INFO] Successfully parsed statement: CALL SYSTEM_CLOCK(ic0, icr, ic)
# start_time = ic0 * 1.0 / icr
# [INFO] Successfully parsed statement: CALL SYSTEM_CLOCK(ic0, icr, ic)
# stop_time = ic0 * 1.0 / icr
# WRITE(*, *) "Execution time : ", stop_time - start_time
# OPEN(UNIT = 1363, FILE = '/home/kardaneh/Fgpt/benchmark/test_procedures/time.txt', STATUS = 'unknown', POSITION =
# 'append')
# WRITE(1363, *) stop_time - start_time
# CLOSE(UNIT = 1363)
# [INFO] Successfully parsed statement: OPEN(UNIT = 1363, FILE =
# '/home/kardaneh/Fgpt/benchmark/test_procedures/output.bin', FORM = 'unformatted', STATUS = 'replace')
# CLOSE(UNIT = 1363)
# [INFO] Successfully updated the main program
# [INFO] Successfully wrote code to file: /home/kardaneh/Fgpt/example_01/test_procedures/main_test_procedures.f90
# [INFO] Compiling and running in /home/kardaneh/Fgpt/example_01/test_procedures...
# Tapenade files detected (adjoint: , tangent: ) - enabling Tapenade runtime
# rm -rf obj test_procedures mod /home/kardaneh/Fgpt/example_01/test_procedures/test_procedures.txt
# Cleaned build artifacts.
# Tapenade files detected (adjoint: , tangent: ) - enabling Tapenade runtime
# rm -rf obj test_procedures mod /home/kardaneh/Fgpt/example_01/test_procedures/test_procedures.txt
# Cleaned build artifacts.
# mpif90 -Wall -g -O0 -Kieee -Ktrap=fp -Mbounds -traceback -r8 -i4 -I/data/ssivanes/modipsl_truck_opt/modeles/IOIPSL/inc -I/data/ssivanes/modipsl_truck_opt/modeles/XIOS/inc -I/data/ssivanes/modipsl_truck_opt/modeles/ORCHIDEE/inc -I/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-c/4.7.4-nvhpc-21.9-3ljfhvpzxouhzpusyuu6s5alubl5el7p/include -I/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-fortran/4.5.3-nvhpc-21.9-nf3dmves2qwgafsadgnawv45fiecf5ss/include -c /home/kardaneh/Fgpt/example_01/test_procedures/module_global_test_procedures.f90 -o obj/module_global_test_procedures.o -module mod >> /home/kardaneh/Fgpt/example_01/test_procedures/test_procedures.txt 2>&1
# mpif90 -Wall -g -O0 -Kieee -Ktrap=fp -Mbounds -traceback -r8 -i4 -I/data/ssivanes/modipsl_truck_opt/modeles/IOIPSL/inc -I/data/ssivanes/modipsl_truck_opt/modeles/XIOS/inc -I/data/ssivanes/modipsl_truck_opt/modeles/ORCHIDEE/inc -I/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-c/4.7.4-nvhpc-21.9-3ljfhvpzxouhzpusyuu6s5alubl5el7p/include -I/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-fortran/4.5.3-nvhpc-21.9-nf3dmves2qwgafsadgnawv45fiecf5ss/include -c /home/kardaneh/Fgpt/example_01/test_procedures/main_test_procedures.f90 -o obj/main_test_procedures.o -module mod >> /home/kardaneh/Fgpt/example_01/test_procedures/test_procedures.txt 2>&1
# mpicc -Wall -g -O0 -Kieee -Ktrap=fp -traceback -DUNDERSCORE -fopenmp -c /data/kardaneh/tapenade/tapenade_3.16/ADFirstAidKit/adStack.c -o obj/adStack.o >> /home/kardaneh/Fgpt/example_01/test_procedures/test_procedures.txt 2>&1
# Linking test_procedures ...
# Including Tapenade object files for automatic differentiation.
# mpif90 -Wall -g -O0 -Kieee -Ktrap=fp -Mbounds -traceback -r8 -i4 obj/module_global_test_procedures.o obj/main_test_procedures.o obj/adStack.o -L/data/ssivanes/modipsl_truck_opt/modeles/ORCHIDEE/lib -lorchidee -L/data/ssivanes/modipsl_truck_opt/modeles/IOIPSL/lib -lioipsl -L/data/ssivanes/modipsl_truck_opt/modeles/XIOS/lib -lxios -lstdc++ -L/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-c/4.7.4-nvhpc-21.9-3ljfhvpzxouhzpusyuu6s5alubl5el7p/lib -lnetcdf -L/net/nfs/tools/u20/22.3/PrgEnv/nvhpc/linux-ubuntu20.04-zen2/netcdf-fortran/4.5.3-nvhpc-21.9-nf3dmves2qwgafsadgnawv45fiecf5ss/lib -lnetcdff -o test_procedures >> /home/kardaneh/Fgpt/example_01/test_procedures/test_procedures.txt 2>&1
# Build complete: test_procedures
# [INFO] Compilation process completed!
# [WARNING] ⚠ Missing files: /home/kardaneh/Fgpt/benchmark/test_procedures/dummy.bin and
# /home/kardaneh/Fgpt/benchmark/test_procedures/global.bin
# [WARNING] ⚠ Benchmark files do not exist yet. Run the modified main code and then python executive.py
# [INFO] Successfully wrote code to file: /home/kardaneh/Fgpt/examples/example_01.f90
# ╭─────────────────────────────────────────────── ✅ Node Complete ────────────────────────────────────────────────╮
# │ Exiting node: Isolated Procedure                                                                                │
# │ Duration: 8.03s                                                                                                 │
# │ ✅ Done isolating → test_procedures                                                                             │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
